# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
df = pd.read_excel('Bankruptcy.xlsx')
df
# Out:
#       NO  D  YR    R1    R2    R3    R4    R5    R6    R7  ...   R15   R16  \
# 0      1  0  78  0.23  0.08  0.02  0.03  0.46  0.12  0.19  ...  0.05  0.57
# 1      2  0  77  0.19  0.07  0.09  0.12  0.02  0.02  0.03  ...  0.09  0.12
# 2      3  0  72  0.07  0.02  0.03  0.05  0.06  0.10  0.14  ... -0.03  0.02
# 3      4  0  80  0.07  0.03  0.04  0.04  0.04  0.06  0.06  ... -0.02  0.01
# 4      5  0  81  0.09  0.02  0.03  0.04  0.06  0.08  0.11  ...  0.02  0.07
# ..   ... ..  ..   ...   ...   ...   ...   ...   ...   ...  ...   ...   ...
# 127  128  1  77  0.27  0.03  0.07  0.10  0.09  0.18  0.26  ...  0.11  0.06
# 128  129  1  77  0.32  0.03  0.03  0.09  0.05  0.06  0.16  ...  0.17  0.07
# 129  130  1  78  0.08  0.01  0.02  0.05  0.04  0.07  0.15  ...  0.19  0.07
# 130  131  1  78  0.14  0.01  0.05  0.07  0.02  0.09  0.14  ...  0.07  0.02
# 131  132  1  78  0.26  0.07  0.12  0.17  0.00  0.01  0.01  ...  0.05  0.04
#
#       R17   R18     R19   R20   R21   R22   R23   R24
# ...

# %%
y = df['D']
x = df['']
# Out:
#                NO           D          YR          R1          R2          R3  \
# count  132.000000  132.000000  132.000000  132.000000  132.000000  132.000000
# mean    66.500000    0.500000   74.015152    0.291742    0.061364    0.073788
# std     38.249183    0.501905    3.064161    0.517893    0.124169    0.080925
# min      1.000000    0.000000   70.000000    0.000000    0.000000    0.000000
# 25%     33.750000    0.000000   72.000000    0.070000    0.020000    0.030000
# 50%     66.500000    0.500000   74.000000    0.150000    0.030000    0.050000
# 75%     99.250000    1.000000   76.000000    0.272500    0.060000    0.090000
# max    132.000000    1.000000   82.000000    4.920000    1.000000    0.640000
#
#                R4          R5          R6          R7  ...         R15  \
# count  132.000000  132.000000  132.000000  132.000000  ...  132.000000
# mean     0.155833    0.041515    0.050227    0.119167  ...    0.087197
# ...

# %%
df.values
# Out:
# array([[1.00e+00, 0.00e+00, 7.80e+01, ..., 4.30e-01, 1.10e-01, 1.70e-01],
#        [2.00e+00, 0.00e+00, 7.70e+01, ..., 6.00e-02, 7.00e-02, 1.00e-01],
#        [3.00e+00, 0.00e+00, 7.20e+01, ..., 3.00e-02, 5.00e-02, 7.00e-02],
#        ...,
#        [1.30e+02, 1.00e+00, 7.80e+01, ..., 7.00e-02, 1.20e-01, 2.60e-01],
#        [1.31e+02, 1.00e+00, 7.80e+01, ..., 2.00e-02, 1.00e-01, 1.40e-01],
#        [1.32e+02, 1.00e+00, 7.80e+01, ..., 5.00e-02, 8.00e-02, 1.20e-01]])
